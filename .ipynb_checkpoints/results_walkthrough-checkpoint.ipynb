# %% [markdown]
# #### Results
#
# In this notebook we will walk through the results we obtained from the paper.
#
# For each experiment we load the pretrained models and generate a grid that displays what the effect is of moving around in the latent space for a given sample.

# %%
# Import all the stuff that we use
import torch
from utils import *
import yaml
from yaml import Loader
from models.models_pl import Generic_model
from models.models_pl import *
from callbacks.generators import *
import torchvision
from IPython.display import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7e68974c1d00> in <module>
#       1 # Import all the stuff that we use
# ----> 2 import torch
#       3 from utils import *
#       4 import yaml
#       5 from yaml import Loader
#
# ModuleNotFoundError: No module named 'torch'

# %%
def prepare_config(path_to_config, local=False):
    '''
    Prepares the config such that it can be used in this file
    
    '''
    
    config = yaml.load(open(path_to_config, "r"), Loader=Loader)
    config = to_vae_config(config)
    if not local:
        config['save_dir'] = './pretrained_models/'
    config = prepare_variables_pl(config)
    return config

def show_experiment_results(config):
    #Loading the encoder and decoder
    encoder, decoder = load_encoder_decoder(config)
    classifier = load_classifier(config)
    # Create model
    model = Generic_model(config, encoder, decoder, classifier, None).to(config['device'])
    train_loader, val_loader = select_dataloader(config)
    x_val = get_x_vals(val_loader, n_classes=config['number_of_classes'],
                   n_for_each_class=config['n_samples_each_class'])
    samples = create_samples(x_val, model, show_prob=config['show_probs'])
    grids = create_latent_grids(samples, config["z_dim"], )
    imgs = []
    for grid in grids:
        tensor = grid.cpu()
        img = torchvision.transforms.ToPILImage()(tensor)
        imgs.append(img)
        display(img)

# %% [markdown]
# ### MNIST 3,8

# %%
mnist_38_config_path = 'config/mnist_3_8.yml'
config = prepare_config(mnist_38_config_path)
show_experiment_results(config)
# Out:
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013A9D0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013A8E0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013ABB0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013A520>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013AB50>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013A910>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013AAC0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800013AB20>

# %% [markdown]
# ### Fashion MNIST 034

# %%
config_path = 'config/fmnist_0_3_4.yml'
config = prepare_config(config_path)
show_experiment_results(config)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-a93f3de38f33> in <module>
#       1 config_path = 'config/fmnist_0_3_4.yml'
#       2 config = prepare_config(config_path)
# ----> 3 show_experiment_results(config)
#
# <ipython-input-2-bdc6a90ca901> in show_experiment_results(config)
#      14     #Loading the encoder and decoder
#      15     encoder, decoder = load_encoder_decoder(config)
# ---> 16     classifier = load_classifier(config)
#      17     # Create model
#      18     model = Generic_model(config, encoder, decoder, classifier, None).to(config['device'])
#
# ~\projects\FACT\utils.py in load_classifier(config)
#      94     # Select the selected classifier architecture and load the pretrained parameters
#      95     classifier = select_classifier(config)
# ---> 96     classifier.load_state_dict(torch.load(config['save_dir'] + config['model_name']))
#      97     return classifier
#      98
#
# c:\users\gerso\anaconda3\envs\dl2020\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1042
#    1043         if len(error_msgs) > 0:
# -> 1044             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1045                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1046         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_CNN:
# 	Missing key(s) in state_dict: "all_modules.0.weight", "all_modules.0.bias", "all_modules.2.weight", "all_modules.2.bias", "all_modules.7.weight", "all_modules.7.bias", "all_modules.10.weight", "all_modules.10.bias".
# 	Unexpected key(s) in state_dict: "step", "epoch", "batch", "model_state_dict_classifier", "optimizer_state_dict", "loss".

# %% [markdown]
# ### Dummy example

# %%
config_path = 'config/dummy.yml'
config = prepare_config(config_path)
show_experiment_results(config)
# Out:
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BF10>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BD00>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BBE0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BDC0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BE20>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BBB0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BEB0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x1800009BE50>

# %%
config_path = 'config_local/cifar_3_8_own.yml'
config = prepare_config(config_path, local=True)
show_experiment_results(config)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-c0dd1d7d7906> in <module>
#       1 config_path = 'config_local/cifar_3_8_own.yml'
#       2 config = prepare_config(config_path, local=True)
# ----> 3 show_experiment_results(config)
#
# <ipython-input-13-5018313e361d> in show_experiment_results(config)
#      14 def show_experiment_results(config):
#      15     #Loading the encoder and decoder
# ---> 16     encoder, decoder = load_encoder_decoder(config)
#      17     classifier = load_classifier(config)
#      18     # Create model
#
# ~\projects\FACT\utils.py in load_encoder_decoder(config)
#     102     encoder, decoder = select_vae_model(config)
#     103
# --> 104     encoder.load_state_dict(torch.load(config['encoder_path']))
#     105     decoder.load_state_dict(torch.load(config['decoder_path']))
#     106     return encoder, decoder
#
# c:\users\gerso\anaconda3\envs\dl2020\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     569         pickle_load_args['encoding'] = 'utf-8'
#     570
# --> 571     with _open_file_like(f, 'rb') as opened_file:
#     572         if _is_zipfile(opened_file):
#     573             # The zipfile reader is going to advance the current file position.
#
# c:\users\gerso\anaconda3\envs\dl2020\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     227 def _open_file_like(name_or_buffer, mode):
#     228     if _is_path(name_or_buffer):
# --> 229         return _open_file(name_or_buffer, mode)
#     230     else:
#     231         if 'w' in mode:
#
# c:\users\gerso\anaconda3\envs\dl2020\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     208 class _open_file(_opener):
#     209     def __init__(self, name, mode):
# --> 210         super(_open_file, self).__init__(open(name, mode))
#     211
#     212     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: './pretrained_models_local/3_8_encoder'
