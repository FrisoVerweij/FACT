# %%
import torch
from utils import *
import yaml
from models.models_pl import Generic_model
from models.models_pl import *
from callbacks.generators import *

# %% [markdown]
# #### MNIST 3,8

# %%
### Here we do some preperations from the config
config = 'config/mnist_3_8_final.yml'
config = yaml.load(open(config, "r"))
config = to_vae_config(config)
config['save_dir'] = './pretrained_models/'
config = prepare_variables_pl(config)

### Because we are using a pretrained global model we need to change the save dir.
# Out:
# <ipython-input-31-cfc8e7c4a7df>:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(open(config, "r"))

# %%
#Loading the encoder and decoder
encoder, decoder = load_encoder_decoder(config)

# %%
classifier = load_classifier(config)

# %%
# Create model
model = Generic_model(config, encoder, decoder, classifier, None).to(config['device'])

# %%
### Next we load the dataset:
train_loader, val_loader = select_dataloader(config)
x_val = get_x_vals(val_loader, n_classes=config['number_of_classes'],
                   n_for_each_class=config['n_samples_each_class'])

# %%
samples = create_samples(x_val, model)

# %%
grids = create_latent_grids(samples, config["z_dim"])

# %%
import torchvision
from IPython.display import Image 
imgs = []
for grid in grids:
    tensor = grid.cpu()
    img = torchvision.transforms.ToPILImage()(tensor)
    imgs.append(img)
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D9262559A0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D9207E7E50>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D92649B9D0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D9032DC2B0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D9032DC820>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D9032DC550>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D9207E7DF0>
# <PIL.Image.Image image mode=RGB size=282x242 at 0x2D926430F10>
