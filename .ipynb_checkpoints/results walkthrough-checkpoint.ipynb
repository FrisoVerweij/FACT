# %%
import torch
from utils import *
import yaml
from models.models_pl import Generic_model
from models.models_pl import *
from callbacks.generators import *

# %% [markdown]
# #### MNIST 3,8

# %%
### Here we do some preperations from the config
config = 'config_local/mnist_3_8_small.yml'
config = yaml.load(open(config, "r"))
config = to_vae_config(config)
config = prepare_variables_pl(config)
# Out:
# <ipython-input-2-c35a2db7f563>:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(open(config, "r"))

# %%
#Loading the encoder and decoder
encoder, decoder = load_encoder_decoder(config)
# Out:
# Encoder(
#   (model): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#     (5): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1))
#     (6): ReLU()
#   )
#   (fc_mu): Linear(in_features=3136, out_features=8, bias=True)
#   (fc_logvar): Linear(in_features=3136, out_features=8, bias=True)
# )

# %%
classifier = load_classifier(config)

# %%
# Create model
model = Generic_model(config, encoder, decoder, classifier, None).to(config['device'])

# %%
### Next we load the dataset:
train_loader, val_loader = select_dataloader(config)
x_val = get_x_vals(val_loader, n_classes=config['number_of_classes'],
                   n_for_each_class=config['n_samples_each_class'])

# %%
samples = create_samples(x_val, model)

# %%
grids = create_latent_grids(samples, config["z_dim"])

# %%
import torchvision
from IPython.display import Image 
imgs = []
for grid in grids:
    tensor = grid.cpu()
    img = torchvision.transforms.ToPILImage()(tensor)
    imgs.append(img)
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=282x322 at 0x287843D1A60>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x28784A14850>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x28784A0DBE0>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x287843D18E0>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x28784A148B0>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x28784A14700>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x28784A14910>
# <PIL.Image.Image image mode=RGB size=282x322 at 0x28784A14940>

# %% [markdown]
# #### Full MNIST

# %% [markdown]
# ### Fashion MNIST 0,3,4
